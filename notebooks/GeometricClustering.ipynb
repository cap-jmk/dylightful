# %% [markdown]
# # Know add the Geometry trajectory

# %%
import pandas as pd
import numpy as np
import json

import matplotlib.pyplot as plt


with open("../tests/1KE7_dynophore_cartesian_time_series.json") as f:
    data = json.load(f)
centroids = data["centroids"]
cartesians = data["cartesian"]

# %%
norms = []
for key in cartesians.keys():
    centre = np.array(centroids[key])
    traj = np.array(cartesians[key])
    print(len(traj))
    norm = np.linalg.norm(traj - centre, axis=1)
    norms.append(norm)
# Out:
# 1001
# 1002
# 40
# 1
# 862
# 126
# 2
# 20
# 80
# 10

# %%
np.array(norms).shape  #
norms[3]
# Out:
# /tmp/ipykernel_58868/3872164429.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(norms).shape#
# array([0.])

# %%
plt.plot(norms[1][:200])

# %%
labels = np.load("labels_1KE7.npy")
plt.plot(labels[:200])np.corrcoef(x, y)

# %%
np.corrcoef(labels, norms[1][:1001])
# Out:
# array([[ 1.        , -0.23020254],
#        [-0.23020254,  1.        ]])
